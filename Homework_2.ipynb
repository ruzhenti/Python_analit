# %% [markdown]
# ## Условие 1:
# ### 1 задача

# %% [markdown]
# #### Скачать файл в уроке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information
# #### Считать данные с помощью pandas

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('kc_house_data.csv', encoding='windows-1251', sep=',')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# #### Вывести на экран первые 5 строк

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# #### Посмотреть на описание признаков и на их содержание

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
## count - количество непропущенных объектов 
## mean - арифметическое среднее
## std - стандартное отклонение
## min - минимальное значение
## 25% - квантиль 25 процентов
## 50% - квантиль 50 процентов или же медиана
## 75% - квантиль 75 процентов
## max - максимальное значение

# %% [markdown]
# ### 2 Задача

# %% [markdown]
# #### Проведите первичный анализ данных
# #### Изучите типы данных
# #### Найдите количество пропущенных ячеек в данных

# %%
df.shape
# Out:
# (21613, 21)

# %%
##размер таблицы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
## типы данных
## int64-целочисленные значения
## float64-вещественные значения
## object -строковые значения

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
## пропущенных данных нет

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
## пропущенных данных нет

# %%
df.describe(include="object")
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
## count - количество непропущенных объектов
## unique - уникальных
## top - самое частотное значение
## freq - частота появления самого частотного значения

# %% [markdown]
# ### 3 Задача

# %% [markdown]
# #### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df["price"].min(), df["price"].max()
# Out:
# (75000.0, 7700000.0)

# %%
## стоимость меняется в диапазоне  от 75 000 до 7 700 000

# %% [markdown]
# #### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
living = df["sqft_living"].sum()
living
# Out:
# 44952873

# %%
lot = df["sqft_lot"].sum()
lot
# Out:
# 326506890

# %%
part = living / lot*100
part
# Out:
# 13.76781757959227

# %%
## жилая площадь составляет 13,8 % от общей площади

# %% [markdown]
# #### 3.3 Как много домов с разными этажами в данных?

# %%
df["floors"].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
df["floors"].nunique()
# Out:
# 6

# %%
## в данных шесть видов домов с разной этажностью

# %% [markdown]
# #### 3.4 Насколько хорошие состояния у домов в данных?

# %%
df['grade'].mean()
# Out:
# 7.656873178179799

# %%
## остояние домов хорошее, т.к.средняя оценка 7,7

# %% [markdown]
# #### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df['yr_built'].min(),df['yr_built'].max()
# Out:
# (1900, 2015)

# %%
## первый дом построили в 1900 году, последний - в 2015 году

# %% [markdown]
# ### 4 Задача

# %% [markdown]
# #### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df['bedrooms']==2] ['price'].mean()
# Out:
# 401372.681884058

# %%
## дома с 2 спальнями в среднем стоят 401372

# %% [markdown]
# #### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %%
## общая площадь домов, у которых стоимость больше 600 000 составляет 20 442,5

# %% [markdown]
# #### 4.3 Как много домов коснулся ремонт?

# %%
df['yr_renovated']
# Out:
# 0           0
# 1        1991
# 2           0
# 3           0
# 4           0
#          ...
# 21608       0
# 21609       0
# 21610       0
# 21611       0
# 21612       0
# Name: yr_renovated, Length: 21613, dtype: int64

# %%
## только один дом претерпел реновацию, состояние остальных домов соответствует датам постройки

# %% [markdown]
# #### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой
# #### grade меньше 4?

# %%
df[df['grade']>=10] ['price'].mean()
# Out:
# 1257984.857579462

# %%
df[df['grade']<=4] ['price'].mean()
# Out:
# 211395.45454545456

# %%
part_price = df[df['grade']>=10] ['price'].mean() / df[df['grade']<=4] ['price'].mean()
part_price
# Out:
# 5.950860486969308

# %%
## стоимость домов с оценкой grade выше 10 больше стоимости домов с оценкой
## grade меньше 4 в 6 разhome_1

# %% [markdown]
# ### 5 Задача

# %% [markdown]
# #### 5.1 Выберите дом клиенту
# #### Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[(df['waterfront'] > 0) & (df['bedrooms'] >= 3) & (df['sqft_basement'] > 0)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 656    3760500116  20141120T000000  3070000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 18914  9253900408  20150408T000000  1400000.0         3       2.75
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
## у клиента 84 варианта

# %% [markdown]
# #### 5.2 Выберите дом клиенту
# #### Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и
# #### год постройки не меньше 1980 года.
# #### В какой ценовом диапазоне будут дома?

# %%
df[(df['waterfront'] > 0)|(df['view'] > 0) & (df['grade'] >=10) & (df['yr_built'] >= 1980)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 185     825059270  20141121T000000  1095000.0         5       3.00
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# ...           ...              ...        ...       ...        ...
# 21505  9468200109  20140617T000000  1555000.0         3       3.50
# 21521  7430500110  20141209T000000  1378000.0         5       3.50
# 21540   715010530  20150113T000000  1881580.0         5       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
## дома нашла, а как диапазон найти не поняла

# %% [markdown]
# #### 5.3 Выберите дом клиенту
# #### Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000.
# #### Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df['sqft_basement']== 0) & (df['floors'] ==2) & (df['price'] <=150000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 11255  1843200350  20140722T000000  150000.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 11255         1360      1934     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# ...

# %%
## оценка по состоянию у таких домов в среднем 7
